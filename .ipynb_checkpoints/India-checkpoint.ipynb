# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import scipy as sp
import plotly.express as px
import plotly
import plotly.graph_objects as go
from plotly.graph_objs import Scatter, Figure, Histogram, Layout, Bar
plotly.offline.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
with open('data.csv') as x:
    ncols = len(x.readline().split(','))

df_raw = pd.read_csv('data.csv', usecols=range(1,ncols))

df = df_raw.copy()

# %%
df.head()
# Out:
#        Zone  State   City                  Name          Type  \
# 0  Northern  Delhi  Delhi            India Gate  War Memorial
# 1  Northern  Delhi  Delhi        Humayun's Tomb          Tomb
# 2  Northern  Delhi  Delhi     Akshardham Temple        Temple
# 3  Northern  Delhi  Delhi  Waste to Wonder Park    Theme Park
# 4  Northern  Delhi  Delhi         Jantar Mantar   Observatory
#
#   Establishment Year  time needed to visit in hrs  Google review rating  \
# 0               1921                          0.5                   4.6
# 1               1572                          2.0                   4.5
# 2               2005                          5.0                   4.6
# 3               2019                          2.0                   4.1
# 4               1724                          2.0                   4.2
#
#    Entrance Fee in INR Airport with 50km Radius Weekly Off   Significance  \
# 0                    0                      Yes        NaN     Historical
# 1                   30                      Yes        NaN     Historical
# 2                   60                      Yes        NaN      Religious
# 3                   50                      Yes     Monday  Environmental
# 4                   15                      Yes        NaN     Scientific
#
#   DSLR Allowed  Number of google review in lakhs Best Time to visit
# 0          Yes                              2.60            Evening
# 1          Yes                              0.40          Afternoon
# 2           No                              0.40          Afternoon
# 3          Yes                              0.27            Evening
# 4          Yes                              0.31            Morning

# %%
# Dataset shape
print(df.shape)
 
rows, columns = df.shape
print(f"The dataset comprises {rows} properties described across {columns} attributes.")
# Out:
# (325, 16)
# The dataset comprises 325 properties described across 16 attributes.

# %%
# Tally the total by data type
type_counts = data_types.value_counts()
 
print(type_counts)
# Out:
# object     11
# float64     3
# int64       2
# Name: count, dtype: int64

# %%
data_types = df.dtypes
 
# View a few datatypes from the dataset (first and last 5 features)
print(data_types)
# Out:
# Unnamed: 0                            int64
# Zone                                 object
# State                                object
# City                                 object
# Name                                 object
# Type                                 object
# Establishment Year                   object
# time needed to visit in hrs         float64
# Google review rating                float64
# Entrance Fee in INR                   int64
# Airport with 50km Radius             object
# Weekly Off                           object
# Significance                         object
# DSLR Allowed                         object
# Number of google review in lakhs    float64
# Best Time to visit                   object
# dtype: object

# %%
# Calculating the percentage of missing values for each column
missing_data = df.isnull().sum()
missing_percentage = (missing_data / len(df)) * 100

# Combining the counts and percentages into a DataFrame for better visualization
missing_info = pd.DataFrame({'Missing Values': missing_data, 'Percentage': missing_percentage})

# Sorting the DataFrame by the percentage of missing values in descending order
missing_info = missing_info.sort_values(by='Percentage', ascending=False)

# Display columns with missing values
print(missing_info[missing_info['Missing Values'] > 0])
# Out:
#             Missing Values  Percentage
# Weekly Off             293   90.153846
# EY_num                 112   34.461538

# %%
# Check the structure of the dataset
print("\nStructure of the dataset:")
print(df.info())
# Out:
# Structure of the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        325 non-null    int64
#  1   Zone                              325 non-null    object
#  2   State                             325 non-null    object
#  3   City                              325 non-null    object
#  4   Name                              325 non-null    object
#  5   Type                              325 non-null    object
#  6   Establishment Year                325 non-null    object
#  7   time needed to visit in hrs       325 non-null    float64
#  8   Google review rating              325 non-null    float64
#  9   Entrance Fee in INR               325 non-null    int64
#  10  Airport with 50km Radius          325 non-null    object
#  11  Weekly Off                        32 non-null     object
#  12  Significance                      325 non-null    object
#  13  DSLR Allowed                      325 non-null    object
#  14  Number of google review in lakhs  325 non-null    float64
#  15  Best Time to visit                325 non-null    object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 40.8+ KB
# None

# %%
# Convert column names to lowercase
df.columns = df.columns.str.lower()

#rename columns to make them easier to work with
df = df.rename(columns = {'establishment year':'year', 'time needed to visit in hrs':'time', 'google review rating':'rating',
                         'entrance fee in inr':'fee', 'airport with 50km radius':'airport', 'weekly off':'off',
                         'dslr allowed':'camera', 'number of google review in lakhs':'reviews', 'best time to visit':'visit'})

# convert Binary columns to numerical
df['camera_num'] = df['camera'].astype('category').cat.codes

df['airport_num'] = df['airport'].astype('category').cat.codes

# Convert 'Establishment Year' to numeric based on conditions
df['year_num'] = df['year'].apply(
    lambda x: int(re.findall('[0-9-]+', x)[0]) if re.findall('[0-9-]+', x) != [] else np.nan).apply(
    lambda x: x * 100 if abs(x) < 100 else x)

# Clean visit column category types
df['visit'] = df['visit'].str.strip().replace('All','Anytime').astype('category')

# %%
#Create column for ratio of fee to time ("Value")
df['cost_ratio'] = df['fee'] / df['time']

# %%
# Descriptive statistics for numerical columns
print(df.describe())
# Out:
#              time      rating          fee     reviews  camera_num  \
# count  325.000000  325.000000   325.000000  325.000000  325.000000
# mean     1.807692    4.486154   115.809231    0.408438    0.815385
# std      0.971398    0.274580   530.859785    0.646668    0.388584
# min      0.500000    1.400000     0.000000    0.010000    0.000000
# 25%      1.000000    4.400000     0.000000    0.059000    1.000000
# 50%      1.500000    4.500000     0.000000    0.170000    1.000000
# 75%      2.000000    4.600000    40.000000    0.500000    1.000000
# max      7.000000    4.900000  7500.000000    7.400000    1.000000
#
#        airport_num     year_num   cost_ratio
# count   325.000000   213.000000   325.000000
# mean      0.698462  1583.042254    43.621720
# std       0.459634   689.989850   185.167754
# min       0.000000 -3500.000000     0.000000
# 25%       0.000000  1503.000000     0.000000
# 50%       1.000000  1864.000000     0.000000
# 75%       1.000000  1976.000000    20.000000
# max       1.000000  2400.000000  2500.000000

# %% [markdown]
# Proceeding with univariate analysis

# %%
x = 'time'

display(df.sort_values(x, ascending = False).head())
display(df.sort_values(x, ascending = True).head())

fig = px.histogram(df, x=x, title = 'Histogram of ' + x, nbins = int(len(df) ** (1 / 2)))

fig.show()
# Out:
#          zone              state       city                     name  \
# 78    Western            Gujarat  Ahmedabad             Science City
# 200  Northern  Jammu and Kashmir   Anantnag            Amarnath Cave
# 110  Southern             Kerala      Kochi  Wonderla Amusement Park
# 15   Northern              Delhi      Delhi  National Science Centre
# 26    Western         Maharastra   Lonavala                 Imagicaa
#
#                type     year  time  rating   fee airport     off  \
# 78          Science     2002   7.0     4.4   500     Yes  Monday
# 200          Temple  Unknown   6.0     4.5     0      No     NaN
# 110  Amusement Park     2016   5.5     4.6   750     Yes     NaN
# 15          Science     1992   5.0     4.4    70     Yes     NaN
# 26   Amusement Park     2013   5.0     1.4  1149      No  Monday
#
#       significance camera  reviews    visit  camera_num  airport_num  \
# 78     Educational    Yes     0.11  Anytime           1            1
# 200      Religious    Yes     0.11  Anytime           1            0
# 110  Entertainment    Yes     0.41  Anytime           1            1
# 15      Scientific    Yes     0.23  Anytime           1            1
# 26    Recreational    Yes     0.95  Anytime           1            0
#
#      year_num  cost_ratio
# 78     2002.0   71.428571
# 200       NaN    0.000000
# 110    2016.0  136.363636
# 15     1992.0   14.000000
# 26     2013.0  229.800000
#          zone        state     city                name          type  \
# 0    Northern        Delhi    Delhi          India Gate  War Memorial
# 220   Eastern  West Bengal   Bolpur  Kankalitala Temple        Temple
# 221   Eastern  West Bengal  Hooghly  Hangseswari Temple        Temple
# 43    Eastern  West Bengal  Kolkata       Howrah Bridge        Bridge
# 208  Northern       Ladakh      Leh       Magnetic Hill  Gravity Hill
#
#         year  time  rating  fee airport  off   significance camera  reviews  \
# 0       1921   0.5     4.6    0     Yes  NaN     Historical    Yes    2.600
# 220  Unknown   0.5     4.7    0     Yes  NaN      Religious     No    0.045
# 221     1814   0.5     4.6    0     Yes  NaN  Architectural     No    0.070
# 43      1943   0.5     4.6    0     Yes  NaN  Architectural     No    1.200
# 208  Unknown   0.5     3.7    0     Yes  NaN         Nature    Yes    0.100
#
#        visit  camera_num  airport_num  year_num  cost_ratio
# 0    Evening           1            1    1921.0         0.0
# 220  Anytime           0            1       NaN         0.0
# 221  Anytime           0            1    1814.0         0.0
# 43   Anytime           0            1    1943.0         0.0
# 208  Anytime           1            1       NaN         0.0

# %%
x = 'rating'

display(df.sort_values(x, ascending = False).head())
display(df.sort_values(x, ascending = True).head())

fig = px.histogram(df, x=x, title = 'Histogram of ' + x, nbins = int(len(df) ** (1 / 2)))

fig.show()
# Out:
#          zone    state           city                             name  \
# 196  Northern   Ladakh            Leh                      Pangong Tso
# 72    Western  Gujarat  Rann of Kutch                       Rann Utsav
# 92   Northern   Punjab       Amritsar  Golden Temple (Harmandir Sahib)
# 94   Northern   Punjab       Amritsar                     Wagah Border
# 207  Northern   Ladakh           Dras                Dras War Memorial
#
#                 type     year  time  rating   fee airport  off significance  \
# 196             Lake  Unknown   2.0     4.9    20     Yes  NaN       Nature
# 72          Cultural  Unknown   3.0     4.9  7500     Yes  NaN     Cultural
# 92    Religious Site     1604   1.5     4.9     0     Yes  NaN    Spiritual
# 94   Border Crossing     1950   2.0     4.8     0     Yes  NaN     Cultural
# 207     War Memorial  Unknown   1.0     4.8     0      No  NaN   Historical
#
#     camera  reviews    visit  camera_num  airport_num  year_num  cost_ratio
# 196    Yes    0.150  Morning           1            1       NaN        10.0
# 72     Yes    0.100  Evening           1            1       NaN      2500.0
# 92     Yes    1.900  Anytime           1            1    1604.0         0.0
# 94     Yes    0.170  Evening           1            1    1950.0         0.0
# 207    Yes    0.012  Anytime           1            0       NaN         0.0
#          zone             state           city                      name  \
# 26    Western        Maharastra       Lonavala                  Imagicaa
# 208  Northern            Ladakh            Leh             Magnetic Hill
# 103  Southern            Kerala      Kumarakom  Kumarakom Bird Sanctuary
# 264  Southern    Andhra Pradesh  Visakhapatnam   Matsyadarshini Aquarium
# 167  Northern  Himachal Pradesh          Kufri           Kufri Fun World
#
#                type     year  time  rating   fee airport     off  \
# 26   Amusement Park     2013   5.0     1.4  1149      No  Monday
# 208    Gravity Hill  Unknown   0.5     3.7     0     Yes     NaN
# 103  Bird Sanctuary     1972   2.0     3.8    50     Yes     NaN
# 264        Aquarium  Unknown   1.0     3.8    20     Yes     NaN
# 167      Ski Resort     1975   5.0     3.8  1500     Yes     NaN
#
#      significance camera  reviews    visit  camera_num  airport_num  year_num  \
# 26   Recreational    Yes     0.95  Anytime           1            0    2013.0
# 208        Nature    Yes     0.10  Anytime           1            1       NaN
# 103      Wildlife    Yes     0.10  Anytime           1            1    1972.0
# 264  Recreational    Yes     0.03  Anytime           1            1       NaN
# 167  Recreational    Yes     0.10  Anytime           1            1    1975.0
#
#      cost_ratio
# 26        229.8
# 208         0.0
# 103        25.0
# 264        20.0
# 167       300.0

# %%
x = 'fee'

display(df.sort_values(x, ascending = False).head())
#display(df.sort_values(x, ascending = True).head())

fig = px.histogram(df, x=x, title = 'Histogram of ' + x, nbins = int(len(df) ** (1 / 2)))

fig.show()
# Out:
#          zone             state           city                         name  \
# 72    Western           Gujarat  Rann of Kutch                   Rann Utsav
# 68    Western           Gujarat       Junagadh            Gir National Park
# 161  Northern  Himachal Pradesh    Bir Billing             Paragliding Site
# 47    Eastern       West Bengal        Kolkata                 Eden Gardens
# 315   Central     Uttar Pradesh  Greater Noida  Buddh International Circuit
#
#                 type     year  time  rating   fee airport     off  \
# 72          Cultural  Unknown   3.0     4.9  7500     Yes     NaN
# 68     National Park     1965   3.0     4.5  3500      No     NaN
# 161  Adventure Sport     2005   2.0     4.8  2500      No     NaN
# 47    Cricket Ground     1864   3.0     4.1  2500     Yes     NaN
# 315       Race Track     2011   2.0     4.6  1500     Yes  Sunday
#
#     significance camera  reviews    visit  camera_num  airport_num  year_num  \
# 72      Cultural    Yes     0.10  Evening           1            1       NaN
# 68      Wildlife    Yes     0.08  Morning           1            0    1965.0
# 161    Adventure    Yes     0.01  Anytime           1            0    2005.0
# 47        Sports    Yes     0.10  Anytime           1            1    1864.0
# 315       Sports    Yes     7.40  Anytime           1            1    2011.0
#
#       cost_ratio
# 72   2500.000000
# 68   1166.666667
# 161  1250.000000
# 47    833.333333
# 315   750.000000

# %%
x = 'reviews'

display(df.sort_values(x, ascending = False).head())
#display(df.sort_values(x, ascending = True).head())

fig = px.histogram(df, x=x, title = 'Histogram of ' + x, nbins = int(len(df) ** (1 / 2)))

fig.show()
# Out:
#          zone          state           city                         name  \
# 315   Central  Uttar Pradesh  Greater Noida  Buddh International Circuit
# 17    Western     Maharastra         Mumbai             Gateway of India
# 0    Northern          Delhi          Delhi                   India Gate
# 111  Southern      Karnataka         Mysore                Mysore Palace
# 181   Central  Uttar Pradesh           Agra                    Taj Mahal
#
#              type  year  time  rating   fee airport     off significance  \
# 315    Race Track  2011   2.0     4.6  1500     Yes  Sunday       Sports
# 17       Monument  1924   1.0     4.6     0     Yes     NaN   Historical
# 0    War Memorial  1921   0.5     4.6     0     Yes     NaN   Historical
# 111        Palace  1912   2.0     4.6    50     Yes     NaN   Historical
# 181     Mausoleum  1632   2.0     4.6    50     Yes  Friday   Historical
#
#     camera  reviews    visit  camera_num  airport_num  year_num  cost_ratio
# 315    Yes     7.40  Anytime           1            1    2011.0       750.0
# 17     Yes     3.60  Anytime           1            1    1924.0         0.0
# 0      Yes     2.60  Evening           1            1    1921.0         0.0
# 111    Yes     2.50  Anytime           1            1    1912.0        25.0
# 181    Yes     2.25  Morning           1            1    1632.0        25.0

# %%
x = 'cost_ratio'

display(df.sort_values(x, ascending = False).head())
#display(df.sort_values(x, ascending = True).head())

fig = px.histogram(df, x=x, title = 'Histogram of ' + x, nbins = int(len(df) ** (1 / 2)))

fig.show()
# Out:
#          zone             state           city                         name  \
# 72    Western           Gujarat  Rann of Kutch                   Rann Utsav
# 161  Northern  Himachal Pradesh    Bir Billing             Paragliding Site
# 68    Western           Gujarat       Junagadh            Gir National Park
# 47    Eastern       West Bengal        Kolkata                 Eden Gardens
# 315   Central     Uttar Pradesh  Greater Noida  Buddh International Circuit
#
#                 type     year  time  rating   fee airport     off  \
# 72          Cultural  Unknown   3.0     4.9  7500     Yes     NaN
# 161  Adventure Sport     2005   2.0     4.8  2500      No     NaN
# 68     National Park     1965   3.0     4.5  3500      No     NaN
# 47    Cricket Ground     1864   3.0     4.1  2500     Yes     NaN
# 315       Race Track     2011   2.0     4.6  1500     Yes  Sunday
#
#     significance camera  reviews    visit  camera_num  airport_num  year_num  \
# 72      Cultural    Yes     0.10  Evening           1            1       NaN
# 161    Adventure    Yes     0.01  Anytime           1            0    2005.0
# 68      Wildlife    Yes     0.08  Morning           1            0    1965.0
# 47        Sports    Yes     0.10  Anytime           1            1    1864.0
# 315       Sports    Yes     7.40  Anytime           1            1    2011.0
#
#       cost_ratio
# 72   2500.000000
# 161  1250.000000
# 68   1166.666667
# 47    833.333333
# 315   750.000000

# %%
# Correlation matrix between numerical variables on clean data
plt.figure(figsize=(8,6))
corr_matrix = df.corr(numeric_only = True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
x = 'time'
y = 'rating'
text = 'name'

#filter outliers
temp_df = df[[x, y]]
temp_df = temp_df.loc[temp_df.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis = 1)]

fig = px.box(temp_df, x=x, y=y)
fig.show()

outliers = df[[x, y]].dropna()
outliers = outliers.loc[~outliers.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis = 1)]
outliers.merge(df, how = 'left', left_index = True, right_index = True, suffixes = ['', '_y'])[[text, x, y]].sort_values(by = y)
# Out:
#                         name  time  rating
# 26                  Imagicaa   5.0     1.4
# 167          Kufri Fun World   5.0     3.8
# 24               Essel World   5.0     4.3
# 15   National Science Centre   5.0     4.4
# 78              Science City   7.0     4.4
# 200            Amarnath Cave   6.0     4.5
# 110  Wonderla Amusement Park   5.5     4.6
# 2          Akshardham Temple   5.0     4.6
# 198             Vaishno Devi   5.0     4.7
# 180        Valley of Flowers   5.0     4.7
# 162              Triund Trek   5.0     4.8

# %%
x = 'year_num'
y = 'rating'
text = 'name'
cat = 'camera'

#filter outliers
temp_df = df[[x, y, cat, text]]
temp_df = temp_df.loc[temp_df[[x,y]].apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis = 1)]
 
fig = px.scatter(temp_df, x=x, y=y, color = cat, hover_name=text,title = y + " vs " + x)
fig.show()

outliers = df[[x, y]].dropna()
outliers = outliers.loc[~outliers.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis = 1)]
outliers.merge(df, how = 'left', left_index = True, right_index = True, suffixes = ['', '_y'])[[text, x, y]].sort_values(by = y)
# Out:
#                              name  year_num  rating
# 26                       Imagicaa    2013.0     1.4
# 229                 Barabati Fort    -987.0     4.5
# 189                  Dhamek Stupa    -500.0     4.6
# 136  Khajuraho Group of Monuments    -850.0     4.7
# 174              Badrinath Temple    -820.0     4.8
# 140     Mahakaleshwar Jyotirlinga   -3500.0     4.8

# %%
#categorical analysis

# %%
fig = px.histogram(df, x="visit")

fig.show()

# %%
x = 'visit'

temp_df = df.groupby(x, observed = False)[['rating']].mean().sort_values('rating', ascending = False)

fig = px.bar(temp_df, y='rating')

fig.update_layout(
    title="Average rating for each "+ x + " category",
    xaxis_title="",
    yaxis_title="rating",)

fig.show()

# %%
fig = px.histogram(df, x="significance").update_xaxes(categoryorder="total descending")

fig.show()

# %%
x = 'significance'

temp_df = df.groupby(x, observed = False)[['rating']].mean().sort_values('rating', ascending = False)

fig = px.bar(temp_df, y='rating')

fig.update_layout(
    title="Average rating for each "+ x + " category",
    xaxis_title="",
    yaxis_title="rating",)

fig.show()

# %%
temp_df = df.groupby('type').filter(lambda x: len(x) > 1)

fig = px.histogram(temp_df, x="type").update_xaxes(categoryorder="total descending")

fig.show()

# %%
temp_df = df.groupby('city').filter(lambda x: len(x) > 1)

fig = px.histogram(temp_df, x="city").update_xaxes(categoryorder="total descending")

fig.show()

# %%
temp_df = df.groupby('state').filter(lambda x: len(x) > 1)

fig = px.histogram(temp_df, x="state").update_xaxes(categoryorder="total descending")

fig.show()

# %%
fig = px.histogram(df, x="zone").update_xaxes(categoryorder="total descending")

fig.show()
